# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
import os

train_horse_dir = os.path.join('/content/drive/My Drive/AI_APP_COLAB/Codelab_Tutorial_Tensorflow/datasets/humans')
train_human_dir = os.path.join('/content/drive/My Drive/AI_APP_COLAB/Codelab_Tutorial_Tensorflow/datasets/horses')

train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])

print('total training horse images:', len(os.listdir(train_horse_dir)))

print('total training human images:', len(os.listdir(train_human_dir)))
