# %%
import zipfile
train_path = "/content/drive/My Drive/AI_APP_COLAB/Kaggle/Intel_Image_Classification/dataset/seg_train.zip"

directory_to_extract_to = "/content/drive/My Drive/AI_APP_COLAB/Kaggle/Intel_Image_Classification/dataset/"

zip_ref = zipfile.ZipFile(train_path, 'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()
